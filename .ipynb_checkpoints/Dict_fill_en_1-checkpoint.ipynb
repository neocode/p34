# %%
import re

with open('EN_polarity_lexicon.txt') as f:
    dic_list = f.readlines()
dic_list = [x.strip('\n') for x in dic_list]
#print(dic_list)
dic = {}
for x in dic_list:   
    x = x.replace(',', '')    
    str_list = x.split()    
    #print(str_list)
    if len(str_list) == 3:
        if (not '_' in str_list[0]) and (float(str_list[2]) != 0):            
            dic[str_list[0]] = [str_list[1].upper(), float(str_list[2])]
print(dic)

with open ('dic_new_en.txt', 'w') as fp:
    for word in dic.keys():
        fp.write("%s %s %s\n" % (word, dic[word][0], dic[word][1]))        
#str_list =  [x.replace(',', '') for x in dic_list]
#print(str_list)
# Out:
# {'sought': ['a', 0.1067], 'innards': ['n', -0.47256], 'trumping': ['n', -0.07997], 'applicative': ['a', 0.15793], 'pussyfoot': ['v', 0.12208], 'armour-plated': ['a', -0.28345], 'cultured': ['a', 0.28755], 'absorbefacient': ['a', 0.17826], 'glamourous': ['a', 0.17826], 'laudator': ['n', 0.21734], 'timely': ['r', 0.28501], 'military': ['n', -0.02501], 'mailing': ['n', 0.0825], 'wealthy': ['a', 0.34255], 'panhandle': ['v', -0.23758], 'unpillared': ['a', -0.0611], 'forehead': ['n', 0.01007], 'demolition': ['n', -0.27255], 'impalpable': ['a', -0.32741], 'thyroid': ['n', -0.18001], 'nettlesome': ['a', -0.3588], 'sensualise': ['v', 0.15199], 'rhythmic': ['a', 0.32502], 'rodent': ['n', -0.36001], 'impatient': ['a', -0.3675], 'collage': ['n', 0.01258], 'playoff': ['n', 0.035], 'thinness': ['n', -0.07806], 'unlimited': ['a', 0.29004], 'holy': ['n', 0.26508], 'carnival': ['n', 0.37002], 'commoner': ['n', -0.14506], 'draft': ['v', 0.07502], 'dangerous': ['a', -0.66758], 'institution': ['n', -0.25006], 'manipulable': ['a', 0.21734], 'fading': ['n', -0.07997], 'disaster': ['n', -0.82251], 'deformed': ['a', -0.68507], 'hypothrombinemia': ['n', -0.07997], 'entrancing': ['a', 0.21734], 'earless': ['a', -0.07997], 'vagabondage': ['n', 0.17826], 'taxpayer': ['n', -0.2375], 'indictment': ['n', -0.27751], 'misconception': ['n', -0.33756], 'putty': ['v', 0.03755], 'crenated': ['a', 0.15793], 'poodle': ['n', 0.27505], 'hearable': ['a', 0.17826], 'detrimental': ['a', -0.42036], 'cinder': ['n', -0.05001], 'sure-enough': ['a', 0.21734], 'lilac': ['n', 0.48752], 'interchangeableness': ['n', 0.15199], 'varnished': ['a', -0.07997], 'nonrandom': ['a', -0.19821], 'runt': ['n', -0.05758], 'oecumenic': ['a', 0.21734], 'parkinsonism': ['n', -0.34088], 'antimagnetic': ['a', -0.28345], 'hasty': ['a', -0.18752], 'randy': ['a', 0.28394], 'spotless': ['a', 0.26259], 'prostyle': ['a', 0.17826], 'muffin': ['n', 0.52501], 'satisfiable': ['a', -0.07997], 'fleshiness': ['n', -0.34088], 'unordered': ['a', -0.43224], 'thrombasthenia': ['n', -0.42036], 'corral': ['v', -0.12509], 'bacteriostatic': ['a', -0.28345], 'mutism': ['n', -0.42036], 'unsymmetric': ['a', -0.0611], 'sellout': ['n', -0.31506], 'coexist': ['v', 0.23759], 'emphasize': ['v', 0.18755], 'remainder': ['v', 0.15753], 'well-found': ['a', 0.21734], 'popeyed': ['a', 0.03284], 'unlawfully': ['r', 0.15793], 'anaesthetic': ['a', -0.16452], 'stroller': ['n', 0.18759], 'megalomania': ['n', -0.34088], 'outline': ['v', 0.025], 'blatancy': ['n', -0.0611], 'backbiter': ['n', 0.21734], 'unshoed': ['a', -0.07997], 'stylishness': ['n', 0.28394], 'otiose': ['a', -0.32551], 'tarquin': ['n', -0.07997], 'derive': ['v', -0.07005], 'exclude': ['v', -0.36259], 'rhumba': ['n', 0.00519], 'complicatedness': ['n', -0.03118], 'apolitical': ['a', 0.15793], 'iodised': ['a', -0.19821], 'sawfish': ['n', 0.15793], 'funkaceae': ['n', -0.19821], 'unprejudiced': ['a', 0.21734], 'uncrystallised': ['a', -0.31182], 'grandson': ['n', 0.30508], 'munja': ['n', -0.07997], 'cirrus': ['n', 0.08459], 'hunky-dory': ['a', 0.17826], 'difference': ['n', -0.02755], 'hazard': ['v', -0.52509], 'huamachil': ['n', 0.17826], 'nationalism': ['n', 0.08519], 'reedy': ['a', 0.10784], 'warning': ['n', -0.38003], 'juncus': ['n', -0.07997], 'postmortem': ['n', -0.45254], 'junkie': ['n', -0.62509], 'windshield': ['n', 0.1], 'appetite': ['n', 0.30752], 'grain': ['v', 0.20759], 'hoarse': ['a', -0.28759], 'rapturous': ['a', -0.1665], 'totalitarianism': ['n', -0.16702], 'shield': ['v', 0.22753], 'magnesium': ['n', -0.01253], 'warehouse': ['v', -0.14257], 'sestet': ['n', 0.08328], 'subclavian': ['a', 0.12208], 'lallation': ['n', -0.11292], 'punctuality': ['n', 0.43007], 'sleeping': ['n', 0.01297], 'changefulness': ['n', 0.20073], 'fourhanded': ['a', -0.07997], 'bogus': ['a', -0.54009], 'titter': ['n', 0.12208], 'viaticus': ['n', -0.19821], 'nickel-and-dime': ['a', -0.14678], 'oafish': ['a', -0.26536], 'echo': ['v', 0.05002], 'edified': ['a', 0.28394], 'shemozzle': ['n', -0.07 ...
